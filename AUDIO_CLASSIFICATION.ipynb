# %% [markdown]
# audio classification using machine learning and deep learning
#
# dataset Environmental dataset kaggle

# %%
#!pip install librosa

# %% [markdown]
# LIBROSA  is a python package for music and audio analysis

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename='C:\\Users\kumar\Downloads/abcd.wav'

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %% [markdown]
# Public API for display tools in IPython.
#
# Create an audio object.

# %%
#!dir

# %%
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveshow(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# The more samples you take - known as the ‘sample rate’ - the more closely the final digital file will resemble the original. A
#
# higher sample rate tends to deliver a better-quality audio reproduction.
#
# Sample rates are usually measured per second, using kilohertz (kHz) or cycles per second

# %%
data
# Out:
# array([-0.00068024, -0.00026258, -0.0003173 , ..., -0.00058308,
#        -0.00148744, -0.00284994], dtype=float32)

# %%
sample_rate
# Out:
# 22050

# %%
#https://www.kdnuggets.com/2020/02/audio-data-analysis-deep-learning-python-part-1.html

# %% [markdown]
# ### A spectrogram visualizing the results of a STFT of the words "nineteenth century". Here frequencies are shown increasing up the vertical axis, and time on the horizontal axis. The legend to the right shows that the color intensity increases with the density.

# %% [markdown]
# ### The Short-Time Fourier Transform (STFT) (or short-term Fourier transform) is a powerful general-purpose tool for audio signal processing . It defines a particularly useful class of time-frequency distributions .which specify complex amplitude versus time and frequency for any signal. We are primarily concerned here with tuning the STFT parameters for the following applications:

# %% [markdown]
# ### Convert an amplitude spectrogram to dB-scaled spectrogram.

# %%
X = librosa.stft(data)    #.stft() converts data into short term Fourier transform.
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sample_rate, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
#!pip install librosa

# %%
data, sample_rate = librosa.load(filename)
#Plot the signal:
plt.figure(figsize=(14, 5))
librosa.display.waveshow(data, sr=sample_rate)
# Zooming in
n0 = 9000
n1 = 9100
plt.figure(figsize=(14, 5))
plt.plot(data[n0:n1])
plt.grid()

# %%
mfccs = librosa.feature.mfcc(data, sr=sample_rate)
print(mfccs.shape)
(20, 97)
#Displaying  the MFCCs:
plt.figure(figsize=(15, 7))
librosa.display.specshow(mfccs, sr=sample_rate, x_axis='time')
# Out:
# (20, 216)
# C:\Users\kumar\AppData\Local\Temp\ipykernel_17056\811329258.py:1: FutureWarning: Pass y=[-0.00068024 -0.00026258 -0.0003173  ... -0.00058308 -0.00148744
#  -0.00284994] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfccs = librosa.feature.mfcc(data, sr=sample_rate)

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio=wav.read(filename)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([ -31,  -22,   -2, ...,  -70,  -86, -104], dtype=int16)

# %%
import pandas as pd

# %% [markdown]
# kaggle AEROPLANE DATA SET

# %%
filename1='C:\\Users\kumar\Downloads/aeroplane.wav'

# %%
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename1)
librosa.display.waveshow(data,sr=sample_rate)
ipd.Audio(filename1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data
# Out:
# array([-0.03731921,  0.04696683,  0.09567288, ...,  0.04411488,
#         0.04187601,  0.04753919], dtype=float32)

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio=wav.read(filename1)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([-801, -847, 1048, ..., 1425, 1481, 1545], dtype=int16)

# %% [markdown]
# AUDIO CLASSIFICATION
#
# data preprocessing

# %%
# lets a read a sample audio using librosa

# %%
import librosa

# %%
audio_file_path='C:\\Users\kumar\Downloads/aeroplane.wav'

# %%
librosa_audio_data,librosa_sample_rate=librosa.load(audio_file_path)

# %%
print(librosa_audio_data)
# Out:
# [-0.03731921  0.04696683  0.09567288 ...  0.04411488  0.04187601
#   0.04753919]

# %% [markdown]
# plot the librosa audio data

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,4))

# %%
plt.plot(librosa_audio_data)

# %% [markdown]
# LIBROSA CONVERTS THE SIGNAL TO MONO

# %%
from scipy.io import wavfile as wav

# %%
wave_sample_rate,wave_audio = wav.read(audio_file_path)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([-801, -847, 1048, ..., 1425, 1481, 1545], dtype=int16)

# %% [markdown]
# original audio with two channels

# %%
plt.figure(figsize=(12,4))

# %%
plt.plot(wave_audio)

# %% [markdown]
# Extract Features
#
# Here we will be using Mel-Frequency Cepstral Coefficients(MFCC) from the audio samples. The MFCC summarises the frequency distribution across the window size, so it is possible to analyse both the frequency and time characteristics of the sound. These audio representations will allow us to identify features for classification.
